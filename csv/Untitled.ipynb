# %%
import pandas as pd
from datetime import datetime
import random

# %%
df = pd.DataFrame()

# %%
l_periodo = []
l_cantidad_corderos = []
l_cantidad_ovejas = []
l_cantidad_carneros = []
l_cantidad_pariciones = []
l_cantidad_muertes_corderos = []
l_cantidad_lana_producida = []
l_cantidad_carne_producida = []
l_rinde_lana = []
l_finura_lana = []

for año in range(2010,2021): #va hasta el 2020
    for mes in range(1,13):
        periodo = datetime.strptime(str(año)+'-'+str(mes)+'-'+'1','%Y-%m-%d').date()
        l_periodo.append(periodo)
        if mes == 1:
            l_cantidad_corderos.append(random.randrange(1,30))
            l_cantidad_ovejas.append(random.randrange(90,110))
            l_cantidad_carneros.append(2)
            l_cantidad_pariciones.append(0)
            l_cantidad_muertes_corderos.append(0)
            l_cantidad_lana_producida.append(random.randrange(3,6)*random.randrange(90,110))
            l_cantidad_carne_producida.append(0)
            l_rinde_lana.append(random.randrange(49,74))
            l_finura_lana.append(random.randrange(15,23))
        if mes == 2:
            l_cantidad_corderos.append(random.randrange(1,15))
            l_cantidad_ovejas.append(random.randrange(90,110))
            l_cantidad_carneros.append(2)
            l_cantidad_pariciones.append(0)
            l_cantidad_muertes_corderos.append(0)
            l_cantidad_lana_producida.append(0)
            l_cantidad_carne_producida.append(0)
            l_rinde_lana.append(0)
            l_finura_lana.append(0)
        if mes == 3:
            l_cantidad_corderos.append(random.randrange(0,10))
            l_cantidad_ovejas.append(random.randrange(90,110))
            l_cantidad_carneros.append(2)
            l_cantidad_pariciones.append(0)
            l_cantidad_muertes_corderos.append(0)
            l_cantidad_lana_producida.append(0)
            l_cantidad_carne_producida.append(0)
            l_rinde_lana.append(0)
            l_finura_lana.append(0)
        if mes == 4:
            l_cantidad_corderos.append(0)
            l_cantidad_ovejas.append(random.randrange(90,110))
            l_cantidad_carneros.append(2)
            l_cantidad_pariciones.append(0)
            l_cantidad_muertes_corderos.append(0)
            l_cantidad_lana_producida.append(0)
            l_cantidad_carne_producida.append(0)
            l_rinde_lana.append(0)
            l_finura_lana.append(0)
        if mes == 5:
            l_cantidad_corderos.append(0)
            l_cantidad_ovejas.append(random.randrange(90,110))
            l_cantidad_carneros.append(2)
            l_cantidad_pariciones.append(0)
            l_cantidad_muertes_corderos.append(0)
            l_cantidad_lana_producida.append(0)
            l_cantidad_carne_producida.append(0)
            l_rinde_lana.append(0)
            l_finura_lana.append(0)
        if mes == 6:
            l_cantidad_corderos.append(0)
            l_cantidad_ovejas.append(random.randrange(90,110))
            l_cantidad_carneros.append(2)
            l_cantidad_pariciones.append(0)
            l_cantidad_muertes_corderos.append(0)
            l_cantidad_lana_producida.append(0)
            l_cantidad_carne_producida.append(0)
            l_rinde_lana.append(0)
            l_finura_lana.append(0)
        if mes == 7:
            l_cantidad_corderos.append(0)
            l_cantidad_ovejas.append(random.randrange(90,110))
            l_cantidad_carneros.append(2)
            l_cantidad_pariciones.append(0)
            l_cantidad_muertes_corderos.append(0)
            l_cantidad_lana_producida.append(0)
            l_cantidad_carne_producida.append(0)
            l_rinde_lana.append(0)
            l_finura_lana.append(0)
        if mes == 8:
            l_cantidad_corderos.append(random.randrange(0,10))
            l_cantidad_ovejas.append(random.randrange(90,110))
            l_cantidad_carneros.append(2)
            l_cantidad_pariciones.append(0)
            l_cantidad_muertes_corderos.append(0)
            l_cantidad_lana_producida.append(0)
            l_cantidad_carne_producida.append(0)
            l_rinde_lana.append(0)
            l_finura_lana.append(0)
        if mes == 9:
            l_cantidad_corderos.append(random.randrange(30,100))
            l_cantidad_ovejas.append(random.randrange(90,100))
            l_cantidad_carneros.append(random.randrange(3,5))
            l_cantidad_pariciones.append(random.randrange(30,100))
            l_cantidad_muertes_corderos.append(random.randrange(5,15))
            l_cantidad_lana_producida.append(random.randrange(3,6)*random.randrange(90,110))
            l_cantidad_carne_producida.append(0)
            l_rinde_lana.append(random.randrange(49,74))
            l_finura_lana.append(random.randrange(15,23))
        if mes == 10:
            l_cantidad_corderos.append(random.randrange(0,10))
            l_cantidad_ovejas.append(random.randrange(90,110))
            l_cantidad_carneros.append(2)
            l_cantidad_pariciones.append(0)
            l_cantidad_muertes_corderos.append(0)
            l_cantidad_lana_producida.append(0)
            l_cantidad_carne_producida.append(0)
            l_rinde_lana.append(0)
            l_finura_lana.append(0)
        if mes == 11:
            l_cantidad_corderos.append(random.randrange(0,10))
            l_cantidad_ovejas.append(random.randrange(90,110))
            l_cantidad_carneros.append(2)
            l_cantidad_pariciones.append(0)
            l_cantidad_muertes_corderos.append(0)
            l_cantidad_lana_producida.append(0)
            l_cantidad_carne_producida.append(0)
            l_rinde_lana.append(0)
            l_finura_lana.append(0)
        if mes == 12:
            l_cantidad_corderos.append(random.randrange(30,100))
            l_cantidad_ovejas.append(random.randrange(90,110))
            l_cantidad_carneros.append(2)
            l_cantidad_pariciones.append(0)
            l_cantidad_muertes_corderos.append(0)
            l_cantidad_lana_producida.append(0)
            l_cantidad_carne_producida.append(0)
            l_rinde_lana.append(0)
            l_finura_lana.append(0)
# Out:
# 2010-01-01
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-23-0c21b0c63086> in <module>
#      16         l_periodo.append(periodo)
#      17         if mes == 1:
# ---> 18             l_cantidad_corderos.append()
#      19             l_cantidad_ovejas.append()
#      20             l_cantidad_carneros.append()
#
# TypeError: append() takes exactly one argument (0 given)

# %%
df.insert(0,'periodo',l_periodo)
df.insert(1,'cantidad_corderos',l_cantidad_corderos)
df.insert(2,'cantidad_ovejas',l_cantidad_ovejas)
df.insert(3,'cantidad_carneros',l_cantidad_carneros)
df.insert(4,'cantidad_pariciones',l_cantidad_pariciones)
df.insert(5,'cantidad_muertes_corderos',l_cantidad_muertes_corderos)
df.insert(6,'cantidad_lana_producida',l_cantidad_lana_producida)
df.insert(7,'cantidad_carne_producida',l_cantidad_carne_producida)
df.insert(8,'rinde_lana',l_rinde_lana)
df.insert(9,'finura_lana'l_finura_lana)

# %%
df.to_csv('datos_produccion.csv', index=False)
